# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# 准备数据

# %%
n = 20
Z = np.random.uniform(0, 1, n)
Z[-1] *= 2
C = [ '%f' % (i/float(n)) for i in range(n)]

# %% [markdown]
# 绘图

# %%
plt.pie(Z, explode=Z*0.05, colors=C)

plt.show()
