# %% [markdown]
# ## 显示背景网格线

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# 准备数据

# %%
X = np.linspace(-np.pi, np.pi, 300)

C = np.cos(X)
S = np.sin(X)

# %% [markdown]
# 绘图

# %%
plt.plot(X, C)
plt.plot(X, S)

plt.grid(True)     # 显示网格线

plt.show()
